# %% [markdown]
# # AVAC-to-WAVE coupling figure
#
# This notebook reads only the archived coupling ledgers and WAVE closure metrics. It can revise the manuscript figure without rerunning either solver.

# %% [markdown]
# ## Reproducible environment
#
# The first code cell installs the repository's validation package and Python dependencies into the active kernel. A clean checkout also needs GNU Make and gfortran to compile the selected solver on first use.

# %%
from pathlib import Path
SEARCH_ROOT = Path.cwd().resolve()
REPOSITORY = next(candidate for candidate in (SEARCH_ROOT, *SEARCH_ROOT.parents) if (candidate / 'validation' / 'pyproject.toml').is_file())
# %pip install -q -e {REPOSITORY / 'validation'}
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from avac4qgis_validation import validation_case
case = validation_case('COUPLING', 'Paper_figures')
CORES = max(1, os.cpu_count() or 1)
case.path
# Out:
# PosixPath('/Users/cmgotelli/Desktop/AVAC-QGIS/validation/COUPLING/Paper_figures')

# %%
case.run('make_coupling_figure.py')
# Out:
# Running: /Users/cmgotelli/anaconda3/bin/python /Users/cmgotelli/Desktop/AVAC-QGIS/validation/COUPLING/Paper_figures/make_coupling_figure.py
# {
#   "figure": "coupling_verification",
#   "source_summary": "/Users/cmgotelli/Desktop/AVAC-QGIS/validation/COUPLING/publication/results/summary.json",
#   "maximum_absolute_wave_relative_closure": 5.6126522638325126e-05,
#   "finest_temporal_volume_relative_error": 0.0005140945167800468,
#   "finest_temporal_momentum_relative_error": 5.8384843804584135e-09,
#   "maximum_diagonal_ledger_relative_error": 0.0005140945167800468
# }

# %%
case.show('../../../docs/article/figures/coupling_verification.png')
