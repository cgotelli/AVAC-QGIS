# %% [markdown]
# # Baines flow over a bump and lake at rest — AVAC and WAVE
#
# Two well-balanced tests are executed with identical grids and boundary data in both solvers: a steady subcritical Baines flow and a closed lake at rest.

# %% [markdown]
# ## Reproducible environment
#
# The first code cell installs the repository's validation package and Python dependencies into the active kernel. A clean checkout also needs GNU Make and gfortran to compile the selected solver on first use.

# %%
from pathlib import Path
SEARCH_ROOT = Path.cwd().resolve()
REPOSITORY = next(candidate for candidate in (SEARCH_ROOT, *SEARCH_ROOT.parents) if (candidate / 'validation' / 'pyproject.toml').is_file())
# %pip install -q -e {REPOSITORY / 'validation'}

# %%
import os
from avac4qgis_validation import validation_case
case = validation_case('WAVE', '07_baines_flow_over_bump')
CORES = max(1, os.cpu_count() or 1)
case.path

# %% [markdown]
# ## Physical and numerical definition
#
# The smooth bump occupies $8<x<12$ m. The steady case uses depth 2 m and discharge 4 m²/s with analytical Bernoulli depth and stage/discharge boundaries. The second case has a horizontal 2 m free surface and closed boundaries.

# %%
case.run(case.path.parent / 'run_baines_validation.py', cwd=case.path.parent)

# %%
summary = case.json('results/summary.json')
summary

# %% [markdown]
# ## Analytical and cross-solver comparison

# %%
case.show('figures/avac_wave_baines_and_lake_at_rest.png')
